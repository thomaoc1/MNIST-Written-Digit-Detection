# %%
import src.cnn.convnet as cnn
import importlib
importlib.reload(cnn)

model = cnn.MNISTConvNet()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_51 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_34 (MaxPooli  (None, 13, 13, 32)        0
#  ng2D)
#
#  conv2d_52 (Conv2D)          (None, 11, 11, 64)        18496
#
#  max_pooling2d_35 (MaxPooli  (None, 5, 5, 64)          0
#  ng2D)
#
#  conv2d_53 (Conv2D)          (None, 3, 3, 64)          36928
#
#  flatten_17 (Flatten)        (None, 576)               0
#
#  dense_34 (Dense)            (None, 64)                36928
#
#  dense_35 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 93322 (364.54 KB)
# Trainable params: 93322 (364.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.train()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1412 - accuracy: 0.9567 - val_loss: 0.0411 - val_accuracy: 0.9861
# Epoch 2/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0456 - accuracy: 0.9854 - val_loss: 0.0385 - val_accuracy: 0.9874
# Epoch 3/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0325 - accuracy: 0.9900 - val_loss: 0.0306 - val_accuracy: 0.9894
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0255 - accuracy: 0.9916 - val_loss: 0.0297 - val_accuracy: 0.9910
# Epoch 5/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0193 - accuracy: 0.9933 - val_loss: 0.0253 - val_accuracy: 0.9923

# %%
model.evaluate()
# Out:
# 313/313 - 0s - loss: 0.0253 - accuracy: 0.9923 - 476ms/epoch - 2ms/step
# [0.025275081396102905, 0.9922999739646912]

# %%
model.plot_history()

# %%
import src.util.evaluation as ev

ev.rec_predict_cnn(model, '../../examples/img')
# Out:
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
