# %%
import src.cnn.convnet as cnn
import importlib
importlib.reload(cnn)

model = cnn.MNISTConvNet()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dense_1 (Dense)             (None, 10)                650
#
# ...
# Total params: 93322 (364.54 KB)
# Trainable params: 93322 (364.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.train()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1447 - accuracy: 0.9552 - val_loss: 0.0551 - val_accuracy: 0.9814
# Epoch 2/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0460 - accuracy: 0.9858 - val_loss: 0.0497 - val_accuracy: 0.9845
# Epoch 3/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0334 - accuracy: 0.9891 - val_loss: 0.0423 - val_accuracy: 0.9864
# Epoch 4/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0241 - accuracy: 0.9926 - val_loss: 0.0302 - val_accuracy: 0.9909
# Epoch 5/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.0307 - val_accuracy: 0.9906

# %%
model.evaluate()
# Out:
# 313/313 - 1s - loss: 0.0307 - accuracy: 0.9906 - 681ms/epoch - 2ms/step
# [0.03067912347614765, 0.9905999898910522]

# %%
model.plot_history()

# %%
import src.util.evaluation as ev

ev.rec_predict_cnn(model, '../../examples/img')
# Out:
# ...
# 1/1 [==============================] - 0s 6ms/step

# %%
import src.util.drawer as drawer
importlib.reload(drawer)

d = drawer.Drawer(model)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# Prediction: 9
