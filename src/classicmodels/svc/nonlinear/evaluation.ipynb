# %%
import src.util.evaluation as ev

PCA_THRESHOLD = .97

# %% [markdown]
# ## Model Training

# %%
import src.classicmodels.svc.nonlinear.nonlinearsvm as nlsvm
import importlib
importlib.reload(nlsvm)

model = nlsvm.NonLinearSVM(pca_threshold=PCA_THRESHOLD)
model
# Out:
# Loading MNIST dataset... Reducing features with PCA... Features reduced (784 -> 214)... Done!
# NonLinearSVM(C=10.0, gamma=0.01)

# %%
model.train()
# Out:
# Training ...
# Done!

# %% [markdown]
# ## Evaluation

# %%
ev.report(model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      1.00      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.98      0.98      0.98      1010
#            4       0.98      0.98      0.98       982
#            5       0.99      0.98      0.98       892
#            6       0.99      0.98      0.99       958
#            7       0.98      0.98      0.98      1028
#            8       0.98      0.98      0.98       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %% [markdown]
# ### Confusion Matrix
# The following confusion matrix replaces all normalised values < 0.01 with 0.0 for better readability.

# %%
ev.confusion_matrix_custom_display(model)

# %% [markdown]
# ### Example Predictions

# %%
ev.recursive_predict(model, '../../../../examples/img')
