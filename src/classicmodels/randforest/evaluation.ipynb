# %%
import src.util.evaluation as ev

PCA_THRESHOLD = .97

# %% [markdown]
# ## Model Training

# %%
import src.classicmodels.randforest.randomforest as rf
import importlib
importlib.reload(rf)

model = rf.RandomForest(pca_threshold=PCA_THRESHOLD)
model
# Out:
# Loading MNIST dataset... Reducing features with PCA... Features reduced (784 -> 214)... Done!
# RandomForest(n_estimators=100, max_depth=None)

# %%
model.train()
# Out:
# Training ...
# Done!

# %% [markdown]
# ## Evaluation

# %%
ev.report(model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       980
#            1       0.98      0.98      0.98      1135
#            2       0.94      0.93      0.94      1032
#            3       0.91      0.94      0.92      1010
#            4       0.92      0.95      0.94       982
#            5       0.94      0.92      0.93       892
#            6       0.96      0.97      0.97       958
#            7       0.96      0.94      0.95      1028
#            8       0.92      0.90      0.91       974
#            9       0.93      0.91      0.92      1009
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %% [markdown]
# ### Confusion Matrix
# The following confusion matrix replaces all normalised values < 0.01 with 0.0 for better readability.

# %%
ev.confusion_matrix_custom_display(model)

# %% [markdown]
# ### Example Predictions

# %%
ev.recursive_predict(model, '../../../examples/img')
